# %% [markdown]
# # Proyek PBA-KEL_JEBAL
# 11S4037 / Pemrosesan Bahasa Alami

# %% [markdown]
# Load Data

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv('restoran.csv')

# %%
restoran = pd.DataFrame(dataset,columns=['Category','Item','Serving Size','Calories','Calories from Fat','Total Fat (% Daily Value)','Saturated Fat','Saturated Fat (% Daily Value)','Trans Fat','Cholesterol','Cholesterol (% Daily Value)','Sodium','Sodium (% Daily Value)','Carbohydrates','Carbohydrates (% Daily Value)','Dietary Fiber','Dietary Fiber (% Daily Value)','Sugars','Protein','Vitamin A (% Daily Value)','Vitamin C (% Daily Value)','Calcium (% Daily Value)','Iron (% Daily Value)'])

# %%
print (restoran)
# Out:
#                Category                                               Item  \
# 0             Beverages                                   Low Fat Milk Jug
# 1             Beverages                        Fat Free Chocolate Milk Jug
# 2              Desserts                              Chocolate Chip Cookie
# 3              Desserts                              Oatmeal Raisin Cookie
# 4              Desserts                                Kids Ice Cream Cone
# 5        Snacks & Sides                                       Apple Slices
# 6        Snacks & Sides                                  Kids French Fries
# 7             Breakfast                      Big Breakfast (Large Biscuit)
# 8           Beef & Pork                 Double Quarter Pounder with Cheese
# 9        Chicken & Fish            Bacon Clubhouse Crispy Chicken Sandwich
# 10   Smoothies & Shakes                 McFlurry with Oreo Cookies (Small)
# ...

# %%
#Sorting
restoran.sort_values(by=['Category'], inplace=True)

# %%
print (restoran)
# Out:
#                Category                                               Item  \
# 204         Beef & Pork                                    Jalapeño Double
# 239         Beef & Pork                                              McRib
# 181         Beef & Pork                                       Cheeseburger
# 165         Beef & Pork                                          Hamburger
# 227         Beef & Pork                                       Daily Double
# 207         Beef & Pork                                     Bacon McDouble
# 236         Beef & Pork                        Quarter Pounder with Cheese
# 197         Beef & Pork                                           McDouble
# 240         Beef & Pork                                            Big Mac
# 208         Beef & Pork                                Double Cheeseburger
# 8           Beef & Pork                 Double Quarter Pounder with Cheese
# ...

# %% [markdown]
# Preprocessing

# %%
#Taking care of missing data
from sklearn.preprocessing import Imputer
imputer = Imputer(missing_values='NaN', strategy='mean', axis=0)
# Out:
# C:\Users\ITD-STU\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)

# %%
print(restoran)
# Out:
#                Category                                               Item  \
# 204         Beef & Pork                                    Jalapeño Double
# 239         Beef & Pork                                              McRib
# 181         Beef & Pork                                       Cheeseburger
# 165         Beef & Pork                                          Hamburger
# 227         Beef & Pork                                       Daily Double
# 207         Beef & Pork                                     Bacon McDouble
# 236         Beef & Pork                        Quarter Pounder with Cheese
# 197         Beef & Pork                                           McDouble
# 240         Beef & Pork                                            Big Mac
# 208         Beef & Pork                                Double Cheeseburger
# 8           Beef & Pork                 Double Quarter Pounder with Cheese
# ...

# %%
# Replace using median 
median = restoran.median()
restoran.fillna(median, inplace=True)

# %%
print(restoran)
# Out:
#                Category                                               Item  \
# 204         Beef & Pork                                    Jalapeño Double
# 239         Beef & Pork                                              McRib
# 181         Beef & Pork                                       Cheeseburger
# 165         Beef & Pork                                          Hamburger
# 227         Beef & Pork                                       Daily Double
# 207         Beef & Pork                                     Bacon McDouble
# 236         Beef & Pork                        Quarter Pounder with Cheese
# 197         Beef & Pork                                           McDouble
# 240         Beef & Pork                                            Big Mac
# 208         Beef & Pork                                Double Cheeseburger
# 8           Beef & Pork                 Double Quarter Pounder with Cheese
# ...
